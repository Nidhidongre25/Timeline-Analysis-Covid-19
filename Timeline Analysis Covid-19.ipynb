# %%
import pandas as pd

# %%
covid = pd.read_csv("Downloads\owid-covid-data.csv")

# %%
covid.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1      AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          1.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          1.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          1.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# ...

# %%
covid.shape
# Out:
# (89029, 59)

# %%
covid["location"].value_counts()
# Out:
# Argentina                          499
# Mexico                             499
# Thailand                           496
# Peru                               494
# Taiwan                             484
#                                   ...
# Tonga                               22
# Sint Maarten (Dutch part)            1
# Tuvalu                               1
# Bonaire Sint Eustatius and Saba      1
# Turkmenistan                         1
# Name: location, Length: 230, dtype: int64

# %%
covid.describe()
# Out:
#         total_cases      new_cases  new_cases_smoothed  total_deaths  \
# count  8.565900e+04   85657.000000        84656.000000  7.589600e+04
# mean   8.762032e+05    5987.102432         5979.191714  2.404947e+04
# std    6.046796e+06   37719.533828        37168.087393  1.425387e+05
# min    1.000000e+00  -74347.000000        -6223.000000  1.000000e+00
# 25%    9.970000e+02       2.000000            7.143000  4.700000e+01
# 50%    1.115400e+04      71.000000           88.143000  3.280000e+02
# 75%    1.181745e+05     783.000000          815.714000  3.187000e+03
# max    1.611761e+08  905992.000000       826374.286000  3.344394e+06
#
#          new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  76054.000000         84656.000000             85197.000000
# mean     141.248915           125.483525             10720.443062
# std      772.094342           708.705298             20378.358953
# min    -1918.000000          -232.143000                 0.001000
# ...

# %%
covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89029 entries, 0 to 89028
# Data columns (total 59 columns):
# iso_code                                 89029 non-null object
# continent                                84281 non-null object
# location                                 89029 non-null object
# date                                     89029 non-null object
# total_cases                              85659 non-null float64
# new_cases                                85657 non-null float64
# new_cases_smoothed                       84656 non-null float64
# total_deaths                             75896 non-null float64
# new_deaths                               76054 non-null float64
# new_deaths_smoothed                      84656 non-null float64
# total_cases_per_million                  85197 non-null float64
# new_cases_per_million                    85195 non-null float64
# new_cases_smoothed_per_million           84199 non-null float64
# ...

# %%
covid.isna().any()
# Out:
# iso_code                                 False
# continent                                 True
# location                                 False
# date                                     False
# total_cases                               True
# new_cases                                 True
# new_cases_smoothed                        True
# total_deaths                              True
# new_deaths                                True
# new_deaths_smoothed                       True
# total_cases_per_million                   True
# new_cases_per_million                     True
# new_cases_smoothed_per_million            True
# total_deaths_per_million                  True
# new_deaths_per_million                    True
# new_deaths_smoothed_per_million           True
# reproduction_rate                         True
# icu_patients                              True
# icu_patients_per_million                  True
# hosp_patients                             True
# ...

# %%
covid.isna().sum()
# Out:
# iso_code                                     0
# continent                                 4748
# location                                     0
# date                                         0
# total_cases                               3370
# new_cases                                 3372
# new_cases_smoothed                        4373
# total_deaths                             13133
# new_deaths                               12975
# new_deaths_smoothed                       4373
# total_cases_per_million                   3832
# new_cases_per_million                     3834
# new_cases_smoothed_per_million            4830
# total_deaths_per_million                 13582
# new_deaths_per_million                   13424
# new_deaths_smoothed_per_million           4830
# reproduction_rate                        17903
# icu_patients                             80020
# icu_patients_per_million                 80020
# hosp_patients                            77808
# ...

# %%
india_case = covid[covid["location"]=="India"]

# %%
india_case.head()
# Out:
#       iso_code continent location        date  total_cases  new_cases  \
# 36786      IND      Asia    India  2020-01-30          1.0        1.0
# 36787      IND      Asia    India  2020-01-31          1.0        0.0
# 36788      IND      Asia    India  2020-02-01          1.0        0.0
# 36789      IND      Asia    India  2020-02-02          2.0        1.0
# 36790      IND      Asia    India  2020-02-03          3.0        1.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 36786                 NaN           NaN         NaN                  NaN  ...
# 36787                 NaN           NaN         NaN                  NaN  ...
# 36788                 NaN           NaN         NaN                  NaN  ...
# 36789                 NaN           NaN         NaN                  NaN  ...
# 36790                 NaN           NaN         NaN                  NaN  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# ...

# %%
india_case.tail()
# Out:
#       iso_code continent location        date  total_cases  new_cases  \
# 37251      IND      Asia    India  2021-05-09   22662575.0   366494.0
# 37252      IND      Asia    India  2021-05-10   22992517.0   329942.0
# 37253      IND      Asia    India  2021-05-11   23340938.0   348421.0
# 37254      IND      Asia    India  2021-05-12   23703665.0   362727.0
# 37255      IND      Asia    India  2021-05-13   24046809.0   343144.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 37251          391008.286      246116.0      3769.0             3879.571  ...
# 37252          387097.714      249992.0      3876.0             3940.571  ...
# 37253          382279.857      254197.0      4205.0             4001.286  ...
# 37254          375179.286      258317.0      4120.0             4021.286  ...
# 37255          365030.143      262317.0      4000.0             4033.429  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# ...

# %%
india_case.shape
# Out:
# (470, 59)

# %%
import seaborn as sns
from matplotlib import pyplot as plt

# %%
sns.set(rc={'figure.figsize':(16,8)})
sns.lineplot(x='date', y='total_cases', data=india_case)
plt.show()

# %%
plt.figure(figsize=(16,8))
plt.bar('total_cases','total_deaths', data=india_case)
plt.xticks(rotation=90)
plt.show()

# %%
fig, ax = plt.subplots(figsize = (10 , 6))
ax.scatter(india_case["total_cases"] , india_case["total_deaths"])
ax.set_xlabel('total_cases')
ax.set_ylabel('total_deaths')
plt.show()
